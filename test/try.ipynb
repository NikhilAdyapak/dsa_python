# %%
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'longestBitonicTrend' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY trends as parameter.
#

def longestBitonicTrend(trends):
    # Write your code here
    len_trends = 0
    arr_trends = []
    i = 0
    high = 0
    low = 0
    counter = 0
    
    while(counter != len(trends)):
        i = counter
        low = trends[i]
        len_trends = 0
        while(i < len(trends)-1):
            i += 1
            if low < trends[i]:
                low = trends[i]
                len_trends += 1
            else:
                high = trends[i]
                len_trends += 1
                break
        while (i < len(trends) -1):
            i += 1
            if high > trends[i]:
                len_trends += 1
                high = trends[i]
            else:
                break
        arr_trends.append(len_trends)
        counter += 1
    return max(arr_trends)        
            
    # for i in range(len(trends)):
    #     for j in range(i, len(trends)):
            
            

if __name__ == '__main__':

    # trends_count = int(input().strip())

    # trends = []

    # for _ in range(trends_count):
    #     trends_item = int(input().strip())
    #     trends.append(trends_item)
    trends = [9, 7,6,2,1]
    trends = [5, 1, 2, 1, 4, 5]

    result = longestBitonicTrend(trends)
    print(result)
# Out:
# 2
